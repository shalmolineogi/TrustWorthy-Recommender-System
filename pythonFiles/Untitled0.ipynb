# %%
import numpy as np
import pandas as pd
import math as m
import matplotlib.pyplot as plt
import time
BASE_DIR = '/content/drive/My Drive/FinalYearProj-2020'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
UserRatings = pd.read_csv(BASE_DIR+'/csvFiles/Netflix Dataset/UserMovieRatings.csv',index_col = 0)
UserRatings.columns.name = 'Movies'
UserRatings.head()
# Out:
# Movies    1   2    3   4   5  ...  193581  193583  193585  193587  193609
# UserID                        ...
# 1       4.0 NaN  4.0 NaN NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2       NaN NaN  NaN NaN NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3       NaN NaN  NaN NaN NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4       NaN NaN  NaN NaN NaN  ...     NaN     NaN     NaN     NaN     NaN
# 5       4.0 NaN  NaN NaN NaN  ...     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 9724 columns]

# %%
r,c=UserRatings.shape
print(r,c)
# Out:
# 610 9724

# %%
# Sparcity check
count_userrating = np.sum((UserRatings.fillna(0) >0), axis=1)
count = np.sum(count_userrating)
total = r*c
sparcity = np.round((total - count )*100/total,3)
print("Sparcity {}".format(sparcity))
# Out:
# Sparcity 98.3

# %%
# Data visualization
count_userrating.shape
# count_userrating.head(100)
plt.hist(count_userrating)
plt.show()

# %%
test_ratio=0.2
test_row=int(r*test_ratio)
train_row=r-test_row

# %%
test=pd.DataFrame(columns=UserRatings.columns)
train=pd.DataFrame(columns=UserRatings.columns)
train=UserRatings[:train_row]
test=UserRatings[train_row:]

# %%
train
# Out:
# BookTitle  1984  1st to Die: A Novel  ...  Zoya  \O\" Is for Outlaw"
# userID                                ...
# 254         9.0                  NaN  ...   NaN                  NaN
# 2276        NaN                  NaN  ...   NaN                  NaN
# 2766        NaN                  NaN  ...   NaN                  NaN
# 2977        NaN                  NaN  ...   NaN                  NaN
# 3363        NaN                  NaN  ...   NaN                  NaN
# ...         ...                  ...  ...   ...                  ...
# 225989      NaN                  0.0  ...   NaN                  NaN
# 226545      NaN                  NaN  ...   NaN                  NaN
# 226879      NaN                  NaN  ...   NaN                  NaN
# 226965      NaN                  NaN  ...   NaN                  NaN
# 227447      NaN                  NaN  ...   NaN                  NaN
#
# [716 rows x 746 columns]

# %%
test
# Out:
# BookTitle  1984  1st to Die: A Novel  ...  Zoya  \O\" Is for Outlaw"
# userID                                ...
# 227520      NaN                  NaN  ...   NaN                  0.0
# 227705      NaN                  NaN  ...   NaN                  NaN
# 228681      NaN                  NaN  ...   NaN                  8.0
# 228764      NaN                 10.0  ...   NaN                  NaN
# 228998      NaN                  NaN  ...   NaN                  0.0
# ...         ...                  ...  ...   ...                  ...
# 275970      0.0                  NaN  ...   NaN                  NaN
# 277427      NaN                  NaN  ...   NaN                  NaN
# 277478      NaN                  NaN  ...   NaN                  NaN
# 277639      NaN                  NaN  ...   NaN                  NaN
# 278418      NaN                  NaN  ...   NaN                  NaN
#
# [178 rows x 746 columns]

# %%
t = pd.DataFrame([[1,2,3],[2,3,4],[3,4,5]])
np.sum(t)
# Out:
# 0     6
# 1     9
# 2    12
# dtype: int64
